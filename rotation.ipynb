# %%
# %load_ext autoreload
# %autoreload 2

from src.rotation import GeoTiffRotator
file_path = 'gis-raw/LC08_L1TP_188020_20130503_20200912_02_T1_refl.tif'  

instance = GeoTiffRotator(file_path)

# %%
instance.display()

# %%
instance.run()
# Out:
# y_padding -6
# x_padding -6

# %%
instance.display()
